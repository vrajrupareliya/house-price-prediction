# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('Data/train.csv', lineterminator = '\n')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
plt.figure(figsize = (15,12))
numeric_df = df.select_dtypes(include=[np.number])

sns.heatmap(numeric_df.corr()['SalePrice'].sort_values(ascending = False).to_frame(),cmap='coolwarm',annot = True)
plt.title("Correlation Matrix of Numeric Features")
plt.show()

# %%
plt.scatter(df['LotArea'],df['SalePrice'])
plt.xlabel(' house size in sqft')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
#understaning data distribution with seaborn
with sns.plotting_context("notebook"):
    g = sns.pairplot(df[['LotArea','SalePrice','LotFrontage','OverallQual','OverallCond']],
                     hue='OverallQual', palette='tab20', height = 6)

# %% [markdown]
# # Data Cleaning

# %%
missing = df.isnull().sum()
missing = missing[missing > 0].sort_values(ascending=False)
print(missing)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# BsmtExposure      38
# BsmtFinType2      38
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# MasVnrArea         8
# Electrical         1
# dtype: int64

# %%
# Categorical columns where NaN means "No such feature"
cat_none = [
    'PoolQC', 'MiscFeature', 'Alley', 'Fence',
    'MasVnrType', 'FireplaceQu', 'GarageType',
    'GarageFinish', 'GarageQual', 'GarageCond',
    'BsmtExposure', 'BsmtFinType2', 'BsmtQual',
    'BsmtCond', 'BsmtFinType1'
]

for col in cat_none:
    df[col] = df[col].fillna('None')

# Numeric columns to fill with 0 or median
df['MasVnrArea'] = df['MasVnrArea'].fillna(0)
df['GarageYrBlt'] = df['GarageYrBlt'].fillna(0)

# LotFrontage: better to impute median per Neighborhood
df['LotFrontage'] = df.groupby('Neighborhood')['LotFrontage'].transform(
    lambda x: x.fillna(x.median())
)


# Electrical: fill with mode
df['Electrical'] = df['Electrical'].fillna(df['Electrical'].mode()[0])

# Double-check
print(df.isnull().sum().sum())  # should be 0
# Out:
# 0

# %%
X = df.select_dtypes(include = [np.number]).drop(['SalePrice', 'Id'], axis = 1)
y = df['SalePrice']

#splitting dataset
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
print(X_train.shape)
print(y_train.shape)
print(df.shape)
# Out:
# (1168, 36)
# (1168,)
# (1460, 81)

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error , mean_squared_error, r2_score

# %%
y_pred = lr.predict(X_test)

# %%
print("MEA", mean_absolute_error(y_test,y_pred))
# Out:
# MEA 21291.721627397317

# %%
print("MSE",(mean_squared_error(y_test,y_pred)))
# Out:
# MSE 961279283.8696105

# %%
print("RMSE", np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE 31004.504251311784

# %%
print("r2_score",(r2_score(y_test,y_pred)))
# Out:
# r2_score 0.8548413217575551

# %% [markdown]
# # Visualize Predicted vs Actual Values

# %%
plt.scatter(y_test, y_pred, alpha=0.5)
plt.xlabel("Actual SalePrice")
plt.ylabel("Predicted SalePrice")
plt.title("Actual vs Predicted Prices")
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')  # perfect fit line
plt.show()

# %% [markdown]
# # Check Residuals (Model Error Pattern)

# %%
residuals = y_test - y_pred

plt.scatter(y_pred, residuals, alpha=0.5)
plt.axhline(y=0, color='red', linestyle='--')
plt.xlabel("Predicted values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %% [markdown]
# # Cross-Validation (Stability Check)

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(lr, X, y, cv=5, scoring='r2')
print("Cross-validation R² scores:", scores)
print("Average R²:", scores.mean())
# Out:
# Cross-validation R² scores: [0.85137434 0.81723051 0.8274737  0.81876817 0.63908325]
# Average R²: 0.7907859946976135

# %% [markdown]
# # Ridge and Lasso Regularization

# %%
from sklearn.linear_model import Ridge, Lasso

ridge = Ridge(alpha=10)
ridge.fit(X_train, y_train)
print("Ridge R²:", ridge.score(X_test, y_test))

lasso = Lasso(alpha=0.001)
lasso.fit(X_train, y_train)
print("Lasso R²:", lasso.score(X_test, y_test))
# Out:
# Ridge R²: 0.8546644764824016
# Lasso R²: 0.8548413235766972

# %%
from sklearn.linear_model import RidgeCV, LassoCV

ridge_cv = RidgeCV(alphas=[0.1, 1, 10, 100], cv=5)
ridge_cv.fit(X_train, y_train)
print("Best alpha (Ridge):", ridge_cv.alpha_)
print("R²:", ridge_cv.score(X_test, y_test))

lasso_cv = LassoCV(alphas=[0.0001, 0.001, 0.01, 0.1], cv=5, max_iter=10000)
lasso_cv.fit(X_train, y_train)
print("Best alpha (Lasso):", lasso_cv.alpha_)
print("R²:", lasso_cv.score(X_test, y_test))
# Out:
# Best alpha (Ridge): 100.0
# R²: 0.8533602724302711
# Best alpha (Lasso): 0.1
# R²: 0.8548415035410759

# %%
import matplotlib.pyplot as plt
y_pred = lasso_cv.predict(X_test)

plt.scatter(y_test, y_pred, alpha=0.6)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted (Lasso)")
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.show()

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

rf = RandomForestRegressor(random_state=42)
rf.fit(X_train, y_train)
print("RandomForest R²:", r2_score(y_test, rf.predict(X_test)))
# Out:
# RandomForest R²: 0.8867659889882757

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
lr.fit(X_scaled, y)
importance = pd.Series(lr.coef_, index=X.columns).sort_values(key=abs, ascending=False)
print(importance.head(10))
# Out:
# OverallQual     23989.654386
# GrLivArea       14088.295093
# GarageCars      11727.818209
# YearBuilt       10431.002661
# 2ndFlrSF         9734.254432
# 1stFlrSF         8198.362483
# TotRmsAbvGrd     8175.934526
# BedroomAbvGr    -8157.798092
# MSSubClass      -7900.918078
# GarageYrBlt     -6800.033431
# dtype: float64

# %%
plt.figure(figsize=(8,6))
importance.sort_values().tail(15).plot(kind='barh', color='skyblue')
plt.title("Standardized Feature Importance (Linear Regression)")
plt.xlabel("Coefficient (Impact on Price)")
plt.show()
